# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# 객체 생성
llm = ChatOpenAI(
    temperature=0.1,  # 창의성 (0.0 ~ 2.0)
    model_name="gpt-5-nano",  # 모델명
)

# %%
# 질의내용
question = "대한민국의 수도는 어디인가요?"

# 질의
print(f"[답변]: {llm.invoke(question)}")
# Out:
# [답변]: content='대한민국의 수도는 서울(서울특별시)です.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 151, 'prompt_tokens': 15, 'total_tokens': 166, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CpaxbRPJzGF7BOiTrFRRs2Qcp2PhA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--70bf6341-2811-44cf-8a05-bc8092156fe2-0' usage_metadata={'input_tokens': 15, 'output_tokens': 151, 'total_tokens': 166, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}

# %%
# TODO : PrepareStocknHeadline을 통해 받은 삼성전자 종가 및 헤드라인 Json을 이용하여 삼성전자의 주가 흐름을 파악해본다.
